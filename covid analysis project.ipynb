# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
a=pd.read_csv("https://raw.githubusercontent.com/SR1608/Datasets/main/covid-data.csv")
a
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# ##  High Level Data Understanding:

# %% [markdown]
# ## a. Find no. of rows & columns in the dataset:

# %%
a.shape
print(len(a.index))  #number of rows
print(len(a.columns))  #number of columns
# Out:
# 57394
# 49

# %% [markdown]
# ##  b. Data types of columns:

# %%
a.dtypes
# Out:
# iso_code                               object
# continent                              object
# location                               object
# date                                   object
# total_cases                           float64
# new_cases                             float64
# new_cases_smoothed                    float64
# total_deaths                          float64
# new_deaths                            float64
# new_deaths_smoothed                   float64
# total_cases_per_million               float64
# new_cases_per_million                 float64
# new_cases_smoothed_per_million        float64
# total_deaths_per_million              float64
# new_deaths_per_million                float64
# new_deaths_smoothed_per_million       float64
# reproduction_rate                     float64
# icu_patients                          float64
# icu_patients_per_million              float64
# hosp_patients                         float64
# ...

# %% [markdown]
# ##  c.Info & describe of data in dataframe.

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 57394 entries, 0 to 57393
# Data columns (total 49 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   iso_code                            57071 non-null  object
#  1   continent                           56748 non-null  object
#  2   location                            57394 non-null  object
#  3   date                                57394 non-null  object
#  4   total_cases                         53758 non-null  float64
#  5   new_cases                           56465 non-null  float64
#  6   new_cases_smoothed                  55652 non-null  float64
#  7   total_deaths                        44368 non-null  float64
#  8   new_deaths                          56465 non-null  float64
#  9   new_deaths_smoothed                 55652 non-null  float64
#  10  total_cases_per_million             53471 non-null  float64
# ...

# %%
a.describe()
# Out:
#         total_cases      new_cases  new_cases_smoothed  total_deaths  \
# count  5.375800e+04   56465.000000        55652.000000  4.436800e+04
# mean   1.677974e+05    1953.576941         1920.431953  6.858639e+03
# std    1.693038e+06   18269.650340        17777.391785  5.578081e+04
# min    1.000000e+00   -8261.000000         -552.000000  1.000000e+00
# 25%    1.800000e+02       0.000000            0.857000  1.300000e+01
# 50%    2.070000e+03      14.000000           19.429000  8.400000e+01
# 75%    2.235675e+04     235.000000          245.286000  7.270000e+02
# max    5.515465e+07  646281.000000       584981.857000  1.328537e+06
#
#          new_deaths  new_deaths_smoothed  total_cases_per_million  \
# count  56465.000000         55652.000000             53471.000000
# mean      47.054317            46.835439              3139.099982
# std      390.853776           378.272794              6183.455260
# min    -1918.000000          -232.143000                 0.001000
# ...

# %% [markdown]
# ## 3. Low Level Data Understanding :

# %% [markdown]
# ## a. Find count of unique values in location column

# %%
len(a['location'].unique())
# Out:
# 216

# %%
a.columns
# Out:
# Index(['iso_code', 'continent', 'location', 'date', 'total_cases', 'new_cases',
#        'new_cases_smoothed', 'total_deaths', 'new_deaths',
#        'new_deaths_smoothed', 'total_cases_per_million',
#        'new_cases_per_million', 'new_cases_smoothed_per_million',
#        'total_deaths_per_million', 'new_deaths_per_million',
#        'new_deaths_smoothed_per_million', 'reproduction_rate', 'icu_patients',
#        'icu_patients_per_million', 'hosp_patients',
#        'hosp_patients_per_million', 'weekly_icu_admissions',
#        'weekly_icu_admissions_per_million', 'weekly_hosp_admissions',
#        'weekly_hosp_admissions_per_million', 'total_tests', 'new_tests',
#        'total_tests_per_thousand', 'new_tests_per_thousand',
#        'new_tests_smoothed', 'new_tests_smoothed_per_thousand',
#        'tests_per_case', 'positive_rate', 'stringency_index', 'population',
#        'population_density', 'median_age', 'aged_65_older', 'aged_70_older',
# ...

# %% [markdown]
# ## b. Find which continent has maximum frequency using values counts

# %%
a[ 'continent'].value_counts().max() #values_counts -->calculate the value count
# Out:
# 14828

# %% [markdown]
# ## c. Find maximum & mean value in 'total_cases'.

# %%
a[ 'total_cases'].value_counts().max()   #max()-->maximum value count
# Out:
# 700

# %%
a[ 'total_cases'].value_counts().mean()  #mean()--->calculate the mean count
# Out:
# 2.371118560338744

# %% [markdown]
# ##  d. Find 25%,50% & 75% quantile value in 'total_deaths'.

# %%
 a['total_deaths'].quantile([0.25,0.5 , 0.75])   #quantile(percentage must be in int not percent values)
# Out:
# 0.25     13.0
# 0.50     84.0
# 0.75    727.0
# Name: total_deaths, dtype: float64

# %% [markdown]
# ## e. Find which continent has maximum_'human_development_index'.

# %%
a.groupby( 'continent')[ 'human_development_index'].max()    #groupby--->is used to split data into groups
# Out:
# continent
# Africa           0.797
# Asia             0.933
# Europe           0.953
# North America    0.926
# Oceania          0.939
# South America    0.843
# Name: human_development_index, dtype: float64

# %% [markdown]
# ##  f. Find which continent has minimum 'gdp_per_capita'

# %%
a.groupby( 'continent')[ 'gdp_per_capita'].min()
# Out:
# continent
# Africa            661.240
# Asia             1479.147
# Europe           5189.972
# North America    1653.173
# Oceania          2205.923
# South America    6885.829
# Name: gdp_per_capita, dtype: float64

# %% [markdown]
# ## 4.Filter the dataframe with only this columns_
# ['continent','location','date','total_cases','total_deaths','gdp_per_ca
# pita','
# human_development_index'] and update the data frame

# %%
c=[ 'continent', 'location', 'date', 'total_cases', 'total_deaths','gdp_per_capita', 'human_development_index']
d=a[c]
d
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# ## 5. Data Cleaning

# %% [markdown]
# ## a. Remove all duplicates observations

# %%
d.drop_duplicates()
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          NaN           NaN
# 1          Asia    Afghanistan  01/01/20          NaN           NaN
# 2          Asia    Afghanistan  02/01/20          NaN           NaN
# 3          Asia    Afghanistan  03/01/20          NaN           NaN
# 4          Asia    Afghanistan  04/01/20          NaN           NaN
# ...         ...            ...       ...          ...           ...
# 57389       NaN  International  13/11/20        696.0           7.0
# 57390       NaN  International  14/11/20        696.0           7.0
# 57391       NaN  International  15/11/20        696.0           7.0
# 57392       NaN  International  16/11/20        696.0           7.0
# 57393       NaN  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# ## b. Find missing values in all columns

# %%
d.isnull().sum()
# Out:
# continent                    646
# location                       0
# date                           0
# total_cases                 3636
# total_deaths               13026
# gdp_per_capita              7027
# human_development_index     8147
# dtype: int64

# %% [markdown]
# ## c.Remove all observations where continent column value is missing
# g

# %%
d.dropna(subset=['continent'])        #dropna ()--->used for remove the missing values
# Out:
#       continent     location      date  total_cases  total_deaths  \
# 0          Asia  Afghanistan  31/12/19          NaN           NaN
# 1          Asia  Afghanistan  01/01/20          NaN           NaN
# 2          Asia  Afghanistan  02/01/20          NaN           NaN
# 3          Asia  Afghanistan  03/01/20          NaN           NaN
# 4          Asia  Afghanistan  04/01/20          NaN           NaN
# ...         ...          ...       ...          ...           ...
# 56743    Africa     Zimbabwe  13/11/20       8696.0         255.0
# 56744    Africa     Zimbabwe  14/11/20       8765.0         257.0
# 56745    Africa     Zimbabwe  15/11/20       8786.0         257.0
# 56746    Africa     Zimbabwe  16/11/20       8786.0         257.0
# 56747    Africa     Zimbabwe  17/11/20       8897.0         257.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
#  ## d. Fill all missing values with 0

# %%
d.fillna(0)    #fillna() -->used for fill the all missing values
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          0.0           0.0
# 1          Asia    Afghanistan  01/01/20          0.0           0.0
# 2          Asia    Afghanistan  02/01/20          0.0           0.0
# 3          Asia    Afghanistan  03/01/20          0.0           0.0
# 4          Asia    Afghanistan  04/01/20          0.0           0.0
# ...         ...            ...       ...          ...           ...
# 57389         0  International  13/11/20        696.0           7.0
# 57390         0  International  14/11/20        696.0           7.0
# 57391         0  International  15/11/20        696.0           7.0
# 57392         0  International  16/11/20        696.0           7.0
# 57393         0  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# ## 6. Date time format :

# %% [markdown]
#  ## a. Convert date column in datetime format using
# pandas.to_datetime

# %%
import warnings
warnings.simplefilter(action='ignore', category=pd.errors.SettingWithCopyWarning)   #prevent the warning error
def convert_date(date_str):
    try:
        return pd.to_datetime(date_str, format='%d/%m/%y', dayfirst=True)
    except ValueError:
        return pd.to_datetime('01/01/1900', format='%d/%m/%y')
d['date'] = d['date'].apply(convert_date)
d["date"]
# Out:
# 0       2019-12-31
# 1       2020-01-01
# 2       2020-01-02
# 3       2020-01-03
# 4       2020-01-04
#            ...
# 57389   2020-11-13
# 57390   2020-11-14
# 57391   2020-11-15
# 57392   2020-11-16
# 57393   2020-11-17
# Name: date, Length: 57394, dtype: datetime64[ns]

# %% [markdown]
# ## b. Create new column month after extracting month data from
# dat
#  column.

# %%
d['month'] = d['date'].dt.month   ##.dt.month ---->create a new column on the table and extracting
d['month']
# Out:
# 0        12
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 57389    11
# 57390    11
# 57391    11
# 57392    11
# 57393    11
# Name: month, Length: 57394, dtype: int32

# %%
d.fillna(0)
# Out:
#       continent       location      date  total_cases  total_deaths  \
# 0          Asia    Afghanistan  31/12/19          0.0           0.0
# 1          Asia    Afghanistan  01/01/20          0.0           0.0
# 2          Asia    Afghanistan  02/01/20          0.0           0.0
# 3          Asia    Afghanistan  03/01/20          0.0           0.0
# 4          Asia    Afghanistan  04/01/20          0.0           0.0
# ...         ...            ...       ...          ...           ...
# 57389         0  International  13/11/20        696.0           7.0
# 57390         0  International  14/11/20        696.0           7.0
# 57391         0  International  15/11/20        696.0           7.0
# 57392         0  International  16/11/20        696.0           7.0
# 57393         0  International  17/11/20        696.0           7.0
#
#        gdp_per_capita  human_development_index
# 0            1803.987                    0.498
# 1            1803.987                    0.498
# ...

# %% [markdown]
# ## 7. Data Aggregation:

# %% [markdown]
# ## . Find max value in all columns using groupby function on
# 'continen'
#  column

# %%
e=d.groupby( 'continent').max()
e
# Out:
#                                    location      date  total_cases  \
# continent
# Africa                             Zimbabwe  31/12/19     752269.0
# Asia                                  Yemen  31/12/19    8874290.0
# Europe                              Vatican  31/12/19    1991233.0
# North America  United States Virgin Islands  31/12/19   11205486.0
# Oceania                   Wallis and Futuna  31/12/19      27750.0
# South America                     Venezuela  31/12/19    5876464.0
#
#                total_deaths  gdp_per_capita  human_development_index
# continent
# Africa              20314.0       26382.287                    0.797
# Asia               130519.0      116935.600                    0.933
# Europe              52147.0       94277.965                    0.953
# North America      247220.0       54225.446                    0.926
# Oceania               907.0       44648.710                    0.939
# ...

# %% [markdown]
# ## Store the result in a new dataframe named 'df_groupby

# %%
df_groupby = d.groupby('continent').max()
df_groupby
# Out:
#                                    location      date  total_cases  \
# continent
# Africa                             Zimbabwe  31/12/19     752269.0
# Asia                                  Yemen  31/12/19    8874290.0
# Europe                              Vatican  31/12/19    1991233.0
# North America  United States Virgin Islands  31/12/19   11205486.0
# Oceania                   Wallis and Futuna  31/12/19      27750.0
# South America                     Venezuela  31/12/19    5876464.0
#
#                total_deaths  gdp_per_capita  human_development_index
# continent
# Africa              20314.0       26382.287                    0.797
# Asia               130519.0      116935.600                    0.933
# Europe              52147.0       94277.965                    0.953
# North America      247220.0       54225.446                    0.926
# Oceania               907.0       44648.710                    0.939
# ...

# %% [markdown]
# ## 8. Feature Engineering :

# %%
a['total_deaths_to_total_cases'] = a['total_deaths'] / a['total_cases']
a['total_deaths_to_total_cases']
# Out:
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#            ...
# 57389    0.010057
# 57390    0.010057
# 57391    0.010057
# 57392    0.010057
# 57393    0.010057
# Name: total_deaths_to_total_cases, Length: 57394, dtype: float64

# %%
a
# Out:
#       iso_code continent       location      date  total_cases  new_cases  \
# 0          AFG      Asia    Afghanistan  31/12/19          NaN        0.0
# 1          AFG      Asia    Afghanistan  01/01/20          NaN        0.0
# 2          AFG      Asia    Afghanistan  02/01/20          NaN        0.0
# 3          AFG      Asia    Afghanistan  03/01/20          NaN        0.0
# 4          AFG      Asia    Afghanistan  04/01/20          NaN        0.0
# ...        ...       ...            ...       ...          ...        ...
# 57389      NaN       NaN  International  13/11/20        696.0        NaN
# 57390      NaN       NaN  International  14/11/20        696.0        NaN
# 57391      NaN       NaN  International  15/11/20        696.0        NaN
# 57392      NaN       NaN  International  16/11/20        696.0        NaN
# 57393      NaN       NaN  International  17/11/20        696.0        NaN
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %% [markdown]
# ## 9. Data Visualization :

# %% [markdown]
# ## a. Perform Univariate analysis on 'gdp_per_capita' column by plotting

# %%
plt.figure(figsize=(10, 6))          #figure--->increase the figure size
plt.hist(a['gdp_per_capita'], bins=10, edgecolor='black',color="red")   #hist--->histogram chart to plot the details
plt.title('Histogram of GDP per Capita')
plt.xlabel('GDP per Capita')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ## b. Plot a scatter plot of 'total_cases' & 'gdp_per_capita'

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='total_cases', y='gdp_per_capita', data=a)  #scatterplot(x,y,data=dataframe value)
plt.title('Scatter Plot of total_cases and gdp_per_capita')
plt.xlabel('total_cases')
plt.ylabel('gdp_per_capita')
plt.show()

# %% [markdown]
# ## c. Plot Pairplot on df_groupby dataset

# %%
sns.pairplot(df_groupby)    #pairplot is used to describe overall plotting the values on the  chart
plt.suptitle('Pair Plot of df_dfgroupby', y=1.02)
plt.show()

# %% [markdown]
# ##  Plot a bar plot of 'continent' column with 'total_cases' .

# %%
sns.barplot(x= 'continent', y= 'total_cases',data=a)
plt.show()

# %%
a.columns
